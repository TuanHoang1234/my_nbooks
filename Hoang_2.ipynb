# %% [markdown]
# # Chapter 2 Assignment

# %% [markdown]
# ## Tuan Hoang

# %%
import pandas as pd

# %%
df = pd.read_csv('ramen-ratings.csv')
df.head()
# Out:
#             Brand                                            Variety Style  \
# 0       New Touch                          T's Restaurant Tantanmen    Cup
# 1        Just Way  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack
# 2          Nissin                      Cup Noodles Chicken Vegetable   Cup
# 3         Wei Lih                      GGE Ramen Snack Tomato Flavor  Pack
# 4  Ching's Secret                                    Singapore Curry  Pack
#
#   Country  Stars
# 0   Japan   3.75
# 1  Taiwan   1.00
# 2     USA   2.25
# 3  Taiwan   2.75
# 4   India   3.75

# %%
df.tail()
# Out:
#          Brand                                            Variety Style  \
# 2572     Vifon  Hu Tiu Nam Vang ["Phnom Penh" style] Asian Sty...  Bowl
# 2573   Wai Wai                     Oriental Style Instant Noodles  Pack
# 2574   Wai Wai                                     Tom Yum Shrimp  Pack
# 2575   Wai Wai                               Tom Yum Chili Flavor  Pack
# 2576  Westbrae                                         Miso Ramen  Pack
#
#        Country  Stars
# 2572   Vietnam    3.5
# 2573  Thailand    1.0
# 2574  Thailand    2.0
# 2575  Thailand    2.0
# 2576       USA    0.5

# %%
df.describe()
# Out:
#              Stars
# count  2577.000000
# mean      3.654676
# std       1.015331
# min       0.000000
# 25%       3.250000
# 50%       3.750000
# 75%       4.250000
# max       5.000000

# %%
df.nunique
# Out:
# <bound method DataFrame.nunique of                Brand                                            Variety Style  \
# 0          New Touch                          T's Restaurant Tantanmen    Cup
# 1           Just Way  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack
# 2             Nissin                      Cup Noodles Chicken Vegetable   Cup
# 3            Wei Lih                      GGE Ramen Snack Tomato Flavor  Pack
# 4     Ching's Secret                                    Singapore Curry  Pack
# ...              ...                                                ...   ...
# 2572           Vifon  Hu Tiu Nam Vang ["Phnom Penh" style] Asian Sty...  Bowl
# 2573         Wai Wai                     Oriental Style Instant Noodles  Pack
# 2574         Wai Wai                                     Tom Yum Shrimp  Pack
# 2575         Wai Wai                               Tom Yum Chili Flavor  Pack
# 2576        Westbrae                                         Miso Ramen  Pack
#
# ...

# %%
vietnam_rows = df[df['Country'] == 'Vietnam']
vietnam_rows
# Out:
#               Brand                                            Variety Style  \
# 18         Binh Tay                                         Mi Hai Cua  Pack
# 52    Uni-President                                    Mushroom Flavor  Pack
# 143        Mum Ngon                                   Lau Tom Chua Cay  Pack
# 224           Vifon  Viet Cuisine Bun Rieu Cua Sour Crab Soup Insta...  Bowl
# 365         Acecook                             Oh! Ricey Pork Flavour  Pack
# ...             ...                                                ...   ...
# 2486       Binh Tay                                   Mi Chay Mushroom  Pack
# 2535        Ve Wong                             Kung-Fu Chicken Flavor  Pack
# 2570        Ve Wong                                      Mushroom Pork  Pack
# 2571          Vifon                                           Nam Vang  Pack
# 2572          Vifon  Hu Tiu Nam Vang ["Phnom Penh" style] Asian Sty...  Bowl
#
#       Country  Stars
# 18    Vietnam   4.00
# ...

# %%
vietnam_brand_style = vietnam_rows[['Brand', 'Style']]
vietnam_brand_style
# Out:
#               Brand Style
# 18         Binh Tay  Pack
# 52    Uni-President  Pack
# 143        Mum Ngon  Pack
# 224           Vifon  Bowl
# 365         Acecook  Pack
# ...             ...   ...
# 2486       Binh Tay  Pack
# 2535        Ve Wong  Pack
# 2570        Ve Wong  Pack
# 2571          Vifon  Pack
# 2572          Vifon  Bowl
#
# [108 rows x 2 columns]

# %%
vietnam_country = vietnam_rows['Country']
vietnam_country
# Out:
# 18      Vietnam
# 52      Vietnam
# 143     Vietnam
# 224     Vietnam
# 365     Vietnam
#          ...
# 2486    Vietnam
# 2535    Vietnam
# 2570    Vietnam
# 2571    Vietnam
# 2572    Vietnam
# Name: Country, Length: 108, dtype: object

# %%
sorted_data = vietnam_rows.sort_values(by='Stars', ascending=False)
sorted_data
# Out:
#               Brand                                            Variety Style  \
# 224           Vifon  Viet Cuisine Bun Rieu Cua Sour Crab Soup Insta...  Bowl
# 2130        Ve Wong                                Little Prince Bacon  Pack
# 2215   Vina Acecook                       Daily Hot & Sour With Shrimp  Pack
# 1722   Vina Acecook                         Bestcook Hot & Sour Shrimp  Bowl
# 2181   Vina Acecook                  Bestcook Hot spicy Tom Yum Shrimp  Bowl
# ...             ...                                                ...   ...
# 1957          Vifon   Phu Gia Bamboo Shoot Artificial Pork Bean Thread  Pack
# 1248          Vifon  Oriental Style Instant Noodle Mi Ga Chicken Fl...   Cup
# 2570        Ve Wong                                      Mushroom Pork  Pack
# 2202          Vifon                            Pho Bo Beef Rice Noodle  Pack
# 52    Uni-President                                    Mushroom Flavor  Pack
#
#       Country  Stars
# 224   Vietnam   5.00
# ...

# %%
df['Country'] = df['Country'].replace('USA', 'United States')
df.to_csv('ramen-ratings.csv', index=False)
df.head()
# Out:
#             Brand                                            Variety Style  \
# 0       New Touch                          T's Restaurant Tantanmen    Cup
# 1        Just Way  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack
# 2          Nissin                      Cup Noodles Chicken Vegetable   Cup
# 3         Wei Lih                      GGE Ramen Snack Tomato Flavor  Pack
# 4  Ching's Secret                                    Singapore Curry  Pack
#
#          Country  Stars
# 0          Japan   3.75
# 1         Taiwan   1.00
# 2  United States   2.25
# 3         Taiwan   2.75
# 4          India   3.75

# %%
num_countries = df['Country'].nunique()
print("Number of countries represented in the data:", num_countries)
# Out:
# Number of countries represented in the data: 37

# %%
average_rating_by_country = df.groupby('Country')['Stars'].mean()
sorted_average_ratings = average_rating_by_country.sort_values(ascending=False)
top_three_countries = sorted_average_ratings.head(3)
top_three_countries
# Out:
# Country
# Brazil      4.350000
# Sarawak     4.333333
# Cambodia    4.200000
# Name: Stars, dtype: float64

# %%
average_rating_by_country = df.groupby('Country')['Stars'].mean()
sorted_average_ratings = average_rating_by_country.sort_values(ascending=False)
bottom_three_countries = sorted_average_ratings.tail(3)
bottom_three_countries
# Out:
# Country
# Netherlands    2.483333
# Canada         2.243902
# Nigeria        1.500000
# Name: Stars, dtype: float64

# %%
# %%time
average_rating_by_country = df.groupby('Country')['Stars'].mean()
sorted_average_ratings = average_rating_by_country.sort_values(ascending=False)
bottom_three_countries = sorted_average_ratings.tail(3)
bottom_three_countries
# Out:
# CPU times: user 2.68 ms, sys: 654 µs, total: 3.33 ms
# Wall time: 3.26 ms
# Country
# Netherlands    2.483333
# Canada         2.243902
# Nigeria        1.500000
# Name: Stars, dtype: float64
